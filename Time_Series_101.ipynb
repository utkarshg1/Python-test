# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarshg1/Python-test/blob/main/Time_Series_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Time Series Decomposition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/AirPassengers.csv"
df = pd.read_csv(url, index_col="Month", parse_dates=True)
df
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %% [markdown]
# ### Date format - yyyy-mm-dd

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.plot(df["Passengers"])
plt.xlabel("Month")
plt.ylabel("Passengers")
plt.title("AirPassengers by month")
plt.grid()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Additive - Trend + Season + Resid
# 2. Multiplicative - Trend x Season x Resid

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
d = seasonal_decompose(df["Passengers"], model="multiplicative")
d.plot()

# %%
# Show the plot for trend
plt.figure(figsize=(10, 5))
plt.plot(df["Passengers"])
d.trend.plot()
plt.xlabel("Month")
plt.ylabel("Passengers")
plt.title("AirPassengers Trendline")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 5))
d.seasonal.plot()
plt.xlabel("Month")
plt.ylabel("Passengers")
plt.title("Season")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 5))
d.resid.plot()
plt.xlabel("Month")
plt.ylabel("Passengers")
plt.title("Residual")
plt.grid()
plt.show()

# %% [markdown]
# ### Time Series decomposition complete

# %% [markdown]
# ### Time Series Forecasting

# %% [markdown]
# ### ARIMA - Auto Regressive Integrated Moving Average
# ARIMA(p, d, q)

# %%
# %pip install pmdarima
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 16.8 MB/s eta 0:00:00
# ...

# %%
from pmdarima.arima import auto_arima

# %%
# Consider 1 year as season 1year = 12months
model = auto_arima(df["Passengers"], seasonal=True, m=12)

# %%
model.order
# Out:
# (2, 1, 1)

# %% [markdown]
# ### ARIMA(2, 1, 1)

# %% [markdown]
# ### Forecast value for next 4 years -> 12*4 = 48 months

# %%
forecast, conf = model.predict(n_periods=48, return_conf_int=True)

# %%
forecast
# Out:
# 1961-01-01    445.634934
# 1961-02-01    420.395024
# 1961-03-01    449.198348
# 1961-04-01    491.839976
# 1961-05-01    503.394502
# 1961-06-01    566.862471
# 1961-07-01    654.260189
# 1961-08-01    638.597493
# 1961-09-01    540.883739
# 1961-10-01    494.126610
# 1961-11-01    423.332690
# 1961-12-01    465.507550
# 1962-01-01    479.290853
# 1962-02-01    454.176837
# 1962-03-01    483.086981
# 1962-04-01    525.819247
# 1962-05-01    537.450681
# 1962-06-01    600.983905
# 1962-07-01    688.436994
# 1962-08-01    672.821280
# 1962-09-01    575.147390
# 1962-10-01    528.424087
# 1962-11-01    457.658868
# 1962-12-01    499.858081
# 1963-01-01    513.662048
# 1963-02-01    488.565565
# 1963-03-01    517.490586
# 1963-04-01    560.235476
# 1963-05-01    571.877620
# 1963-06-01    635.419933
# 1963-07-01    722.880733
# 1963-08-01    707.271562
# 1963-09-01    609.603224
# 1963-10-01    562.884632
# 1963-11-01    492.123410
# 1963-12-01    534.326015
# 1964-01-01    548.132860
# ...

# %%
conf
# Out:
# array([[423.34484757, 467.92501952],
#        [394.23539679, 446.55465213],
#        [419.83171141, 478.56498452],
#        [460.37625926, 523.30369276],
#        [470.38045292, 536.40855182],
#        [532.69931939, 601.02562216],
#        [619.22112948, 689.29924892],
#        [602.87983183, 674.31515457],
#        [504.63120707, 577.13627077],
#        [457.44583825, 530.80738157],
#        [386.30372821, 460.36165208],
#        [428.1911891 , 502.82391072],
#        [433.49735818, 525.08434836],
#        [405.10869698, 503.24497681],
#        [431.1554372 , 535.01852521],
#        [471.84033434, 579.79816045],
#        [481.87334967, 593.02801195],
#        [544.15634767, 657.81146303],
#        [630.60850683, 746.26548123],
#        [614.17889589, 731.46366422],
#        [515.83210925, 634.46267142],
#        [468.54379213, 588.30438119],
#        [397.29693225, 518.02080357],
#        [439.07958457, 560.63657678],
#        [446.3268565 , 580.99723894],
# ...

# %%
df_fo = pd.DataFrame(forecast, columns=["forecast"])
df_fo.head()
# Out:
#               forecast
# 1961-01-01  445.634934
# 1961-02-01  420.395024
# 1961-03-01  449.198348
# 1961-04-01  491.839976
# 1961-05-01  503.394502

# %%
df_fo[["Low", "High"]] = conf

# %%
df_fo = df_fo.round(0)
df_fo
# Out:
#             forecast    Low   High
# 1961-01-01     446.0  423.0  468.0
# 1961-02-01     420.0  394.0  447.0
# 1961-03-01     449.0  420.0  479.0
# 1961-04-01     492.0  460.0  523.0
# 1961-05-01     503.0  470.0  536.0
# 1961-06-01     567.0  533.0  601.0
# 1961-07-01     654.0  619.0  689.0
# 1961-08-01     639.0  603.0  674.0
# 1961-09-01     541.0  505.0  577.0
# 1961-10-01     494.0  457.0  531.0
# 1961-11-01     423.0  386.0  460.0
# 1961-12-01     466.0  428.0  503.0
# 1962-01-01     479.0  433.0  525.0
# 1962-02-01     454.0  405.0  503.0
# 1962-03-01     483.0  431.0  535.0
# 1962-04-01     526.0  472.0  580.0
# 1962-05-01     537.0  482.0  593.0
# 1962-06-01     601.0  544.0  658.0
# 1962-07-01     688.0  631.0  746.0
# 1962-08-01     673.0  614.0  731.0
# 1962-09-01     575.0  516.0  634.0
# 1962-10-01     528.0  469.0  588.0
# 1962-11-01     458.0  397.0  518.0
# 1962-12-01     500.0  439.0  561.0
# 1963-01-01     514.0  446.0  581.0
# 1963-02-01     489.0  418.0  559.0
# ...

# %%
df_fo.to_csv("Forecast.csv", index_label="Month")

# %% [markdown]
# ### Visualize the forecast

# %%
plt.figure(figsize=(10, 5))
plt.plot(df["Passengers"], label="observed")
plt.fill_between(df_fo.index, df_fo["Low"], df_fo["High"], color="pink", alpha=0.9, label="confidence")
plt.plot(df_fo["forecast"], label="forecast")
plt.xlabel("Month")
plt.ylabel("Passengers")
plt.title("AirPassengers Forecast")
plt.legend()
plt.grid()
plt.show()
